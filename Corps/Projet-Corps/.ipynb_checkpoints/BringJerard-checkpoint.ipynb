# %% [markdown]
# # Equations de Bring Jerard

# %% [markdown]
# Il s'agit des équations du type
#
# $x^5+x+a=0$   avec $a$ une constante rationelle.
#
# Pour s'y faire, l'on va écrire ces équations de la forme $P(x)=0$ avec $P \in \mathbb Q[X]$

# %%
# %display latex

# %% [markdown]
# #### Avant de commencer
# On va se servir de plusieurs outils qui nous aideront pour les affichages graphiques

# %%
import networkx as nx
import hashlib

# %%
#génarateur de couleurs 
def generateurcouleurs(i):
    hex_dig=hashlib.md5(str(i).encode()).hexdigest()
    return f"#{hex_dig[:6]}"

# %% [markdown]
# ### Construction des objets qui vont nous servir

# %%
PRQ.<X> = PolynomialRing(QQ)
PRR.<Y> = PolynomialRing(RR)
var('x') #pour les affichages
# Out:
# x

# %%
#On définit une fonction qui nous renverra un polynôme de Bring-Jerard
def BringJerard(a):
    P = X^5+X+a
    return P

def BringJerardReel(a):
    P = Y^5+Y+a
    return P

# %% [markdown]
# ## Exemple d'un polynôme de Bring-Jerard
# #### Travaux sur un polynôme de Bring-Jerard
#
# On va commencer par le cas $a=5$, c'est à dire le polynôme $P=X^5+X+5$

# %%
P = BringJerard(5)
P.factor()
# Out:
# X^5 + X + 5

# %% [markdown]
# #### Affichage

# %%
tr_P = x^5+x+5
plot(tr_P,(x,-5,5),
     ymin=0,ymax=30,color="blue")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
P.is_irreducible()
# Out:
# True

# %% [markdown]
# On a $P$ est bien un polynôme irréductible.

# %% [markdown]
# #### Recherche de ses racines réelles :

# %%
Pr = BringJerardReel(5)
Pr.roots()
# Out:
# [(-1.29915279219022, 1)]

# %% [markdown]
# Ce polynôme admet donc une seule racine réelle et deux paires de racines complexes conjuguées.

# %% [markdown]
# #### Application de la théorie de Galois sur ce polynôme :

# %% [markdown]
# On veut d'abord calculer le corps $\frac{\mathbb Q [X] }{(P)_\text{id}}$.
#
#
# On sait que ça sera un corps car $P$ est irréductible.

# %%
K.<alpha> = NumberField(P)
print(K)
# Out:
# Number Field in alpha with defining polynomial X^5 + X + 5

# %% [markdown]
# Calculons maintenant son groupe de Galois à partir de son corps de décomposition :

# %%
G = K.galois_group()
print(G)
# Out:
# Galois group 5T5 (S5) with order 120 of X^5 + X + 5

# %% [markdown]
# Ce groupe est en bijection avec $S_5$ le groupe des permutations entre 5 éléments. On sait qu'il n'est pas résoluble.

# %% [markdown]
# ## Travaux sur plusieurs polynômes de Bring Jerard

# %% [markdown]
# On va commencer par afficher plusieurs polynômes en faisant varier $a$ de 1 à 20.

# %%
tracés=[]
for i in range(1,21):
    couleur=generateurcouleurs(i)
    tracé = plot(x^5+x+i,(x,-5,5),
                 ymin=0,ymax=30,color=couleur)
    tracés.append(tracé)

tracé=sum(tracés)
tracé.show(figsize=(10,6))
# Out:
# Graphics object consisting of 20 graphics primitives

# %% [markdown]
# On peut voir qu'elles semblent admettre une seule racine réelles.

# %%
for i in range(100):
    P = BringJerard(i)
    if P.is_irreducible():
        K.<alpha> = NumberField(P)
        G = K.galois_group()
        print(K,G)
    else:
        print("l'équation X^5+X+",i," n'est pas irréductible")

# %% [markdown]
# #### Recherche des racines réelles et irréductibilité des polynômes

# %%
Polynômes=[]
for i in range(1,21):
    Polynômes.append(BringJerard(i))

for P in Polynômes:
    if P.is_irreducible():
        print(P," est irréductible")
    else:
        print(P," n'est pas irréductible")
# Out:
# X^5 + X + 1  n'est pas irréductible
# X^5 + X + 2  n'est pas irréductible
# X^5 + X + 3  est irréductible
# X^5 + X + 4  est irréductible
# X^5 + X + 5  est irréductible
# X^5 + X + 6  n'est pas irréductible
# X^5 + X + 7  est irréductible
# X^5 + X + 8  est irréductible
# X^5 + X + 9  est irréductible
# X^5 + X + 10  est irréductible
# X^5 + X + 11  est irréductible
# X^5 + X + 12  est irréductible
# X^5 + X + 13  est irréductible
# X^5 + X + 14  est irréductible
# X^5 + X + 15  est irréductible
# X^5 + X + 16  est irréductible
# X^5 + X + 17  est irréductible
# X^5 + X + 18  est irréductible
# X^5 + X + 19  est irréductible
# X^5 + X + 20  est irréductible

# %% [markdown]
# Elles ne sont pas toutes irréductibles.

# %%
for i in range(1,21):
    print("les racines réelles de ",P,"sont :",BringJerardReel(i).roots())
# Out:
# les racines réelles de  X^5 + X + 20 sont : [(-0.754877666246693, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.00000000000000, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.13299756588507, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.22633935308771, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.29915279219022, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.35930408597178, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.41081385105958, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.45602337717474, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.49642066077801, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.53301279864698, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.56651456314424, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.59745245776147, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.62622606783280, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.65314619249339, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.67845958817174, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.70236561032161, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.72502775061060, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.74658184580084, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.76714205151190, 1)]
# les racines réelles de  X^5 + X + 20 sont : [(-1.78680527598683, 1)]

# %% [markdown]
# Comme on l'avait dit, elles admettent une seule racine réelle de multiplicité 1.

# %% [markdown]
# ### Application de la théorie de Galois sur ces polynômes :
# Nous allons d'abord calculer $\frac{\mathbb Q[X]}{(P)_{id}}$ uniquement si $P$ est irréductible.
#
# Pour s'y faire, la méthode `.is_irreducible`va nous être très utile.

# %%
for P in Polynômes:
    if P.is_irreducible():
        K.<alpha> = NumberField(P)
        print(K)
    else:
        print(P,"n'est pas irréductible")
# Out:
# X^5 + X + 1 n'est pas irréductible
# X^5 + X + 2 n'est pas irréductible
# Number Field in alpha with defining polynomial X^5 + X + 3
# Number Field in alpha with defining polynomial X^5 + X + 4
# Number Field in alpha with defining polynomial X^5 + X + 5
# X^5 + X + 6 n'est pas irréductible
# Number Field in alpha with defining polynomial X^5 + X + 7
# Number Field in alpha with defining polynomial X^5 + X + 8
# Number Field in alpha with defining polynomial X^5 + X + 9
# Number Field in alpha with defining polynomial X^5 + X + 10
# Number Field in alpha with defining polynomial X^5 + X + 11
# Number Field in alpha with defining polynomial X^5 + X + 12
# Number Field in alpha with defining polynomial X^5 + X + 13
# Number Field in alpha with defining polynomial X^5 + X + 14
# Number Field in alpha with defining polynomial X^5 + X + 15
# Number Field in alpha with defining polynomial X^5 + X + 16
# Number Field in alpha with defining polynomial X^5 + X + 17
# Number Field in alpha with defining polynomial X^5 + X + 18
# Number Field in alpha with defining polynomial X^5 + X + 19
# Number Field in alpha with defining polynomial X^5 + X + 20

# %% [markdown]
# Calculons maintenant les groupes de Galois et voyons s'ils sont récolvables ou non

# %%
for P in Polynômes:
    if P.is_irreducible():
        K.<alpha> = NumberField(P)
        G = K.galois_group()
        print(G)
# Out:
# Galois group 5T5 (S5) with order 120 of X^5 + X + 3
# Galois group 5T5 (S5) with order 120 of X^5 + X + 4
# Galois group 5T5 (S5) with order 120 of X^5 + X + 5
# Galois group 5T5 (S5) with order 120 of X^5 + X + 7
# Galois group 5T5 (S5) with order 120 of X^5 + X + 8
# Galois group 5T5 (S5) with order 120 of X^5 + X + 9
# Galois group 5T5 (S5) with order 120 of X^5 + X + 10
# Galois group 5T5 (S5) with order 120 of X^5 + X + 11
# Galois group 5T5 (S5) with order 120 of X^5 + X + 12
# Galois group 5T5 (S5) with order 120 of X^5 + X + 13
# Galois group 5T5 (S5) with order 120 of X^5 + X + 14
# Galois group 5T5 (S5) with order 120 of X^5 + X + 15
# Galois group 5T5 (S5) with order 120 of X^5 + X + 16
# Galois group 5T5 (S5) with order 120 of X^5 + X + 17
# Galois group 5T5 (S5) with order 120 of X^5 + X + 18
# Galois group 5T5 (S5) with order 120 of X^5 + X + 19
# Galois group 5T5 (S5) with order 120 of X^5 + X + 20

# %% [markdown]
# Ils sont tous en bijection avec $S_5$ le groupe des permutations entre 5 éléments. On sait qu'il n'est pas résoluble.

# %% [markdown]
# #### Allons plus loin
#
# Essayons de calculer le groupe de Galois pour les 100 polynômes de Bring Jerard avec $a \in [1,100]$

# %%
for i in range(1,101):
    P = BringJerard(i)
    if P.is_irreducible():
        K.<alpha> = NumberField(P)
        G = K.galois_group()
        print(G)
    else:
        print(P," n'est pas irréductible")
# Out:
# X^5 + X + 1  n'est pas irréductible
# X^5 + X + 2  n'est pas irréductible
# Galois group 5T5 (S5) with order 120 of X^5 + X + 3
# Galois group 5T5 (S5) with order 120 of X^5 + X + 4
# Galois group 5T5 (S5) with order 120 of X^5 + X + 5
# X^5 + X + 6  n'est pas irréductible
# Galois group 5T5 (S5) with order 120 of X^5 + X + 7
# Galois group 5T5 (S5) with order 120 of X^5 + X + 8
# Galois group 5T5 (S5) with order 120 of X^5 + X + 9
# Galois group 5T5 (S5) with order 120 of X^5 + X + 10
# Galois group 5T5 (S5) with order 120 of X^5 + X + 11
# Galois group 5T5 (S5) with order 120 of X^5 + X + 12
# Galois group 5T5 (S5) with order 120 of X^5 + X + 13
# Galois group 5T5 (S5) with order 120 of X^5 + X + 14
# Galois group 5T5 (S5) with order 120 of X^5 + X + 15
# Galois group 5T5 (S5) with order 120 of X^5 + X + 16
# Galois group 5T5 (S5) with order 120 of X^5 + X + 17
# Galois group 5T5 (S5) with order 120 of X^5 + X + 18
# Galois group 5T5 (S5) with order 120 of X^5 + X + 19
# Galois group 5T5 (S5) with order 120 of X^5 + X + 20
# Galois group 5T5 (S5) with order 120 of X^5 + X + 21
# Galois group 5T5 (S5) with order 120 of X^5 + X + 22
# Galois group 5T5 (S5) with order 120 of X^5 + X + 23
# Galois group 5T5 (S5) with order 120 of X^5 + X + 24
# Galois group 5T5 (S5) with order 120 of X^5 + X + 25
# Galois group 5T5 (S5) with order 120 of X^5 + X + 26
# Galois group 5T5 (S5) with order 120 of X^5 + X + 27
# Galois group 5T5 (S5) with order 120 of X^5 + X + 28
# Galois group 5T5 (S5) with order 120 of X^5 + X + 29
# Galois group 5T5 (S5) with order 120 of X^5 + X + 30
# Galois group 5T5 (S5) with order 120 of X^5 + X + 31
# Galois group 5T5 (S5) with order 120 of X^5 + X + 32
# Galois group 5T5 (S5) with order 120 of X^5 + X + 33
# X^5 + X + 34  n'est pas irréductible
# Galois group 5T5 (S5) with order 120 of X^5 + X + 35
# Galois group 5T5 (S5) with order 120 of X^5 + X + 36
# Galois group 5T5 (S5) with order 120 of X^5 + X + 37
# Galois group 5T5 (S5) with order 120 of X^5 + X + 38
# Galois group 5T5 (S5) with order 120 of X^5 + X + 39
# Galois group 5T5 (S5) with order 120 of X^5 + X + 40
# Galois group 5T5 (S5) with order 120 of X^5 + X + 41
# Galois group 5T5 (S5) with order 120 of X^5 + X + 42
# Galois group 5T5 (S5) with order 120 of X^5 + X + 43
# Galois group 5T5 (S5) with order 120 of X^5 + X + 44
# Galois group 5T5 (S5) with order 120 of X^5 + X + 45
# Galois group 5T5 (S5) with order 120 of X^5 + X + 46
# Galois group 5T5 (S5) with order 120 of X^5 + X + 47
# Galois group 5T5 (S5) with order 120 of X^5 + X + 48
# Galois group 5T5 (S5) with order 120 of X^5 + X + 49
# Galois group 5T5 (S5) with order 120 of X^5 + X + 50
# Galois group 5T5 (S5) with order 120 of X^5 + X + 51
# Galois group 5T5 (S5) with order 120 of X^5 + X + 52
# Galois group 5T5 (S5) with order 120 of X^5 + X + 53
# Galois group 5T5 (S5) with order 120 of X^5 + X + 54
# Galois group 5T5 (S5) with order 120 of X^5 + X + 55
# Galois group 5T5 (S5) with order 120 of X^5 + X + 56
# Galois group 5T5 (S5) with order 120 of X^5 + X + 57
# Galois group 5T5 (S5) with order 120 of X^5 + X + 58
# Galois group 5T5 (S5) with order 120 of X^5 + X + 59
# Galois group 5T5 (S5) with order 120 of X^5 + X + 60
# Galois group 5T5 (S5) with order 120 of X^5 + X + 61
# Galois group 5T5 (S5) with order 120 of X^5 + X + 62
# Galois group 5T5 (S5) with order 120 of X^5 + X + 63
# Galois group 5T5 (S5) with order 120 of X^5 + X + 64
# Galois group 5T5 (S5) with order 120 of X^5 + X + 65
# Galois group 5T5 (S5) with order 120 of X^5 + X + 66
# Galois group 5T5 (S5) with order 120 of X^5 + X + 67
# Galois group 5T5 (S5) with order 120 of X^5 + X + 68
# Galois group 5T5 (S5) with order 120 of X^5 + X + 69
# Galois group 5T5 (S5) with order 120 of X^5 + X + 70
# Galois group 5T5 (S5) with order 120 of X^5 + X + 71
# Galois group 5T5 (S5) with order 120 of X^5 + X + 72
# Galois group 5T5 (S5) with order 120 of X^5 + X + 73
# Galois group 5T5 (S5) with order 120 of X^5 + X + 74
# Galois group 5T5 (S5) with order 120 of X^5 + X + 75
# Galois group 5T5 (S5) with order 120 of X^5 + X + 76
# Galois group 5T5 (S5) with order 120 of X^5 + X + 77
# Galois group 5T5 (S5) with order 120 of X^5 + X + 78
# Galois group 5T5 (S5) with order 120 of X^5 + X + 79
# Galois group 5T5 (S5) with order 120 of X^5 + X + 80
# Galois group 5T5 (S5) with order 120 of X^5 + X + 81
# Galois group 5T5 (S5) with order 120 of X^5 + X + 82
# Galois group 5T5 (S5) with order 120 of X^5 + X + 83
# Galois group 5T5 (S5) with order 120 of X^5 + X + 84
# Galois group 5T5 (S5) with order 120 of X^5 + X + 85
# Galois group 5T5 (S5) with order 120 of X^5 + X + 86
# Galois group 5T5 (S5) with order 120 of X^5 + X + 87
# Galois group 5T5 (S5) with order 120 of X^5 + X + 88
# Galois group 5T5 (S5) with order 120 of X^5 + X + 89
# Galois group 5T5 (S5) with order 120 of X^5 + X + 90
# Galois group 5T5 (S5) with order 120 of X^5 + X + 91
# Galois group 5T5 (S5) with order 120 of X^5 + X + 92
# Galois group 5T5 (S5) with order 120 of X^5 + X + 93
# Galois group 5T5 (S5) with order 120 of X^5 + X + 94
# Galois group 5T5 (S5) with order 120 of X^5 + X + 95
# Galois group 5T5 (S5) with order 120 of X^5 + X + 96
# Galois group 5T5 (S5) with order 120 of X^5 + X + 97
# Galois group 5T5 (S5) with order 120 of X^5 + X + 98
# Galois group 5T5 (S5) with order 120 of X^5 + X + 99
# Galois group 5T5 (S5) with order 120 of X^5 + X + 100
