# %%
# %display latex

# %%
for i in range(10):
    X=1/2^i
    print(X)
# Out:
# 1
# 1/2
# 1/4
# 1/8
# 1/16
# 1/32
# 1/64
# 1/128
# 1/256
# 1/512

# %%
var('x')
f = arctan(x)

plot(f,(x,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive
